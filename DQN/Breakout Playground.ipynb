# %%
# %matplotlib inline

import gym
import numpy as np
from matplotlib import pyplot as plt

# %%
env = gym.make("Breakout-v0", render_mode='rgb_array')
# Out:
# /home/deeproute/anaconda3/envs/rl_learn/lib/python3.8/site-packages/gym/envs/registration.py:555: UserWarning: WARN: The environment Breakout-v0 is out of date. You should consider upgrading to version `v4`.
#   logger.warn(
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]

# %%
print("Action space size: {}".format(env.action_space.n))
print(env.get_action_meanings()) # env.unwrapped.get_action_meanings() for gym 0.8.0 or later

observation = env.reset()[0]
print("Observation space shape: {}".format(observation.shape))

plt.figure()
img = env.render()
plt.imshow(img)

[env.step(2) for x in range(1)]
plt.figure()
img = env.render()
plt.imshow(img)

env.close()
# Out:
# /home/deeproute/anaconda3/envs/rl_learn/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:289: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(
# Action space size: 4
# ['NOOP', 'FIRE', 'RIGHT', 'LEFT']
# Observation space shape: (210, 160, 3)

# %%
# Check out what a cropped image looks like
cropped = observation[34:-16,:,:]
plt.imshow(cropped)
print(cropped.shape)
# Out:
# (160, 160, 3)
